# %%
# import related libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
#load data
df=pd.read_csv(r"C:\Users\HP\Downloads\student_performance_data.csv")

# %%
#dimension
df.shape
# Out:
# (100, 6)

# %%
#Show first five row of data
df.head()
# Out:
#    StudentID  StudyHours  SleepHours  AttendanceRate  Participation  TestScore
# 0          1        7.06        8.11           82.20           3.16      79.86
# 1          2        3.94        5.38           95.63           6.64      66.87
# 2          3        4.36         NaN          100.00           8.01        NaN
# 3          4        3.76         NaN           91.96           6.66      68.05
# 4          5        3.98        6.54           86.54           7.84      63.20

# %%
#Show last five row of data
df.tail()
# Out:
#     StudentID  StudyHours  SleepHours  AttendanceRate  Participation  \
# 95         96        4.54        7.19          100.00           6.14
# 96         97        0.04        6.58           97.90           3.42
# 97         98        1.70        6.08           70.22           8.00
# 98         99        4.08        6.55           87.14           9.34
# 99        100        1.17        4.38           82.59           8.96
#
#     TestScore
# 95      74.05
# 96      38.47
# 97      42.89
# 98      84.02
# 99      54.00

# %%
#information about data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   StudentID       100 non-null    int64
#  1   StudyHours      97 non-null     float64
#  2   SleepHours      97 non-null     float64
#  3   AttendanceRate  100 non-null    float64
#  4   Participation   100 non-null    float64
#  5   TestScore       97 non-null     float64
# dtypes: float64(5), int64(1)
# memory usage: 4.8 KB

# %%
df.describe()
# Out:
#         StudentID  StudyHours  SleepHours  AttendanceRate  Participation  \
# count  100.000000   97.000000   97.000000      100.000000     100.000000
# mean    50.500000    3.251649    6.452784       85.237000       5.966600
# std     29.011492    1.558961    1.027601        9.988643       2.089859
# min      1.000000    0.000000    4.000000       57.640000       0.890000
# 25%     25.750000    2.080000    5.730000       77.247500       4.520000
# 50%     50.500000    3.290000    6.540000       86.330000       6.050000
# 75%     75.250000    4.080000    7.150000       93.610000       7.422500
# max    100.000000    7.060000    8.990000      100.000000      10.000000
#
#        TestScore
# count  97.000000
# mean   59.403608
# std    11.490708
# min    29.060000
# 25%    51.310000
# 50%    60.000000
# 75%    67.880000
# max    86.940000

# %%
#findings null values
df.isnull().sum()
# Out:
# StudentID         0
# StudyHours        3
# SleepHours        3
# AttendanceRate    0
# Participation     0
# TestScore         3
# dtype: int64

# %%
#removing null values
df.dropna(inplace=True)

# %%
#finding duplicates
df.duplicated().sum()
# Out:
# 0

# %%
df.describe()
# Out:
#         StudentID  StudyHours  SleepHours  AttendanceRate  Participation  \
# count   92.000000   92.000000   92.000000       92.000000      92.000000
# mean    51.065217    3.248804    6.451196       85.338152       5.887717
# std     28.555250    1.591249    1.041082        9.933946       2.144046
# min      1.000000    0.000000    4.000000       57.640000       0.890000
# 25%     26.750000    1.897500    5.730000       77.617500       4.367500
# 50%     51.500000    3.285000    6.535000       86.330000       5.920000
# 75%     74.250000    4.087500    7.155000       93.657500       7.422500
# max    100.000000    7.060000    8.990000      100.000000      10.000000
#
#        TestScore
# count  92.000000
# mean   59.071413
# std    11.650612
# min    29.060000
# 25%    50.810000
# 50%    59.955000
# 75%    67.667500
# max    86.940000

# %%
studyhours=df["StudyHours"].to_numpy()
print("Avg_hours:",np.mean(studyhours))
print("std_hours:",np.std(studyhours))
print()
testscore=df["TestScore"].to_numpy()
print("Avg_hours:",np.mean(testscore))
print("std_hours:",np.std(testscore))
# Out:
# Avg_hours: 3.248804347826087
# std_hours: 1.5825775909210404
#
# Avg_hours: 59.07141304347828
# std_hours: 11.587120246722382

# %%
corr=np.corrcoef(studyhours,testscore)[0,1]
print("Correlation(studyhours V/S testscore)",corr)
# Out:
# Correlation(studyhours V/S testscore) 0.6798605268246632

# %%
df.corr()
# Out:
#                 StudentID  StudyHours  SleepHours  AttendanceRate  \
# StudentID        1.000000   -0.118231   -0.118038       -0.065370
# StudyHours      -0.118231    1.000000    0.125120        0.012145
# SleepHours      -0.118038    0.125120    1.000000        0.036074
# AttendanceRate  -0.065370    0.012145    0.036074        1.000000
# Participation   -0.030046   -0.018337   -0.157955       -0.074374
# TestScore       -0.185127    0.679861    0.068602        0.219194
#
#                 Participation  TestScore
# StudentID           -0.030046  -0.185127
# StudyHours          -0.018337   0.679861
# SleepHours          -0.157955   0.068602
# AttendanceRate      -0.074374   0.219194
# Participation        1.000000   0.490986
# TestScore            0.490986   1.000000

# %%
sns.heatmap(df.corr(numeric_only=True),annot=True)
plt.title("corrlation")
plt.show()

# %%
sns.pairplot(df[["StudyHours","SleepHours","AttendanceRate","Participation","TestScore"]])
plt.title("pairplot")
plt.show()

# %%
print(df.StudyHours.unique())
# Out:
# [7.06 3.94 3.98 2.52 1.73 3.91 0.   4.11 3.79 2.12 3.28 1.86 1.6  4.43
#  3.29 5.97 6.91 4.03 5.54 0.44 1.26 2.8  3.59 3.25 4.21 3.11 3.96 2.25
#  1.87 1.58 3.73 2.82 5.85 3.36 5.99 3.3  1.3  3.   4.54 2.77 2.95 3.97
#  6.23 2.08 2.48 3.22 2.28 3.84 1.61 5.79 3.92 3.58 6.13 2.44 3.35 4.02
#  4.55 5.91 1.49 1.89 1.9  0.93 5.22 4.44 4.49 1.43 4.94 0.8  2.26 3.33
#  1.72 5.31 4.   2.15 5.11 1.64 2.41 0.04 1.7  4.08 1.17]

# %%
df.describe()
# Out:
#         StudentID  StudyHours  SleepHours  AttendanceRate  Participation  \
# count   92.000000   92.000000   92.000000       92.000000      92.000000
# mean    51.065217    3.248804    6.451196       85.338152       5.887717
# std     28.555250    1.591249    1.041082        9.933946       2.144046
# min      1.000000    0.000000    4.000000       57.640000       0.890000
# 25%     26.750000    1.897500    5.730000       77.617500       4.367500
# 50%     51.500000    3.285000    6.535000       86.330000       5.920000
# 75%     74.250000    4.087500    7.155000       93.657500       7.422500
# max    100.000000    7.060000    8.990000      100.000000      10.000000
#
#        TestScore
# count  92.000000
# mean   59.071413
# std    11.650612
# min    29.060000
# 25%    50.810000
# 50%    59.955000
# 75%    67.667500
# max    86.940000

# %%
sns.boxplot(x=pd.cut(df["StudyHours"],bins=[0,2,4,6,8]),y="TestScore",data=df)
plt.show()

# %%
sns.scatterplot(x="StudyHours",y="TestScore",data=df)
plt.show()
